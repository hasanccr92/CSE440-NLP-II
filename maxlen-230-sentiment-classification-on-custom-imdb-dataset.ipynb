# %% [markdown]
# # **This notebook is prepared as a project for the reqirement of the course CSE440-Natural Language Processing II of Brac University.**

# %% [markdown]
# **In this notebook, we have used 3 different approaches for sentiment classification on a customized IMDB Dataset. Workflow--->**
# * **Importing/installing necessary libraries**
# * **EDA**
# * **Text Data Preprocessing**
# * **Loading a Pre-trained vector and making an Embedding matrix**
# * **RNN Training and testing**
# * **LSTM Training and testing**
# * **BiLSTM Training and testing**
# * **Result Visualization**

# %% [markdown]
# # Importing/installing necessary libraries

# %%
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')

import matplotlib.pyplot as plt
import seaborn as sns

import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, Dense
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.optimizers import Adam

import os
import warnings

warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Creating a dynamic data path**

# %%
'''input the path of the directory 
containing both files '''

dir = '/kaggle/input/'  

for dirname, _, filenames in os.walk(dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        if filename.endswith('.txt'):
            vecPath = os.path.join(dirname, filename)
        else:
            dataPath = os.path.join(dirname, filename)
# Out:
# /kaggle/input/imdb-for-440-project/glove.6B.100d.txt
# /kaggle/input/imdb-for-440-project/imdb_440/IMDB Dataset.csv

# %% [markdown]
# # EDA

# %%
df = pd.read_csv(dataPath)
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(df.dtypes)

# Check for missing values
print(df.isnull().sum())
# Out:
# review       object
# sentiment    object
# dtype: object
# review       0
# sentiment    0
# dtype: int64

# %%
df.sentiment.unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
#data distribution
#balance check

sentiment_distribution = df['sentiment'].value_counts()

# Plotting the distribution
plt.bar(sentiment_distribution.index, sentiment_distribution.values, color=['red', 'green'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ![rsz_thanos-perfectly-balanced-as-all-things-should-be.jpg](attachment:3ff44880-3019-4245-a7be-71c8625ced4b.jpg)

# %%
# Calculate text lengths
df['text_length'] = df['review'].apply(len)

# Plot histogram
plt.figure(figsize=(5, 3))
plt.hist(df['text_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# Tokenize the text
df['token_length'] = df['review'].apply(lambda x: len(word_tokenize(x)))

# Plot histogram 
plt.figure(figsize=(5, 3))
plt.hist(df['token_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Token Lengths')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Preprocessing the text data

# %%
# binary encode sentiments
encoder = LabelEncoder()
df['sentiment'] = encoder.fit_transform(df['sentiment'])

def preprocess_text(text):
    #html tag handling
    text = re.sub(r'<[^>]+>', '', text)

    # Lowercasing
    text = text.lower()

    # Tokenization
    tokens = word_tokenize(text)

    #punctuation and stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]

#     stemmer = PorterStemmer()
#     tokens = [stemmer.stem(word) for word in tokens]

    return ' '.join(tokens)
df['cleaned_review'] = df['review'].apply(preprocess_text)

# Compare the two
print(df[['review', 'cleaned_review']].head())
# Out:
#                                               review  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...
#
#                                       cleaned_review
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically family little boy jake thinks zombie...
# 4  petter mattei love time money visually stunnin...

# %% [markdown]
# # Loading GloVe and making an Embedding Matrix

# %%
def load_glove_vectors(glovePath):
    embedding_index = {}
    with open(glovePath, 'r', encoding='utf8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embedding_index[word] = coefs
    return embedding_index

# Load GloVe Vectors
glove_vectors = load_glove_vectors(vecPath)

# Tokenize, text ---> sequences
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['cleaned_review'])  
sequences = tokenizer.texts_to_sequences(df['cleaned_review'])

# Create an embedding matrix
embedding_dim = 100
vocab_size = len(tokenizer.word_index) + 1
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in tokenizer.word_index.items():
    embedding_vector = glove_vectors.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# **Train-test split and padding**

# %%
X = sequences  
y = df['sentiment'].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Padding sequences
maxlen = 230  # Maximum length of all sequences
X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %% [markdown]
# # Training and testing on RNN

# %%
# Building the model
rnn_model = Sequential()
rnn_model.add(Embedding(input_dim=vocab_size, 
                    output_dim=embedding_dim, 
                    weights=[embedding_matrix], 
                    input_length=maxlen, 
                    trainable=False))
rnn_model.add(Flatten())  # Flatten the output of the embedding layer
rnn_model.add(Dense(10, activation='relu'))
rnn_model.add(Dense(1, activation='sigmoid'))  

# optimizer = Adam(learning_rate=1e-3)
rnn_model.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])

rnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 230, 100)          10018200
#
#  flatten (Flatten)           (None, 23000)             0
#
#  dense (Dense)               (None, 10)                230010
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10248221 (39.09 MB)
# Trainable params: 230021 (898.52 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
# Training the model

history_rnn = rnn_model.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 9s 4ms/step - loss: 0.5943 - accuracy: 0.7017 - val_loss: 0.5371 - val_accuracy: 0.7466
# Epoch 2/20
# 2000/2000 [==============================] - 9s 4ms/step - loss: 0.4670 - accuracy: 0.7943 - val_loss: 0.5096 - val_accuracy: 0.7646
# Epoch 3/20
# 2000/2000 [==============================] - 9s 5ms/step - loss: 0.3960 - accuracy: 0.8297 - val_loss: 0.5106 - val_accuracy: 0.7706
# Epoch 4/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.3561 - accuracy: 0.8480 - val_loss: 0.5611 - val_accuracy: 0.7602
# Epoch 5/20
# 2000/2000 [==============================] - 9s 4ms/step - loss: 0.3253 - accuracy: 0.8599 - val_loss: 0.5694 - val_accuracy: 0.7567
# Epoch 6/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2984 - accuracy: 0.8709 - val_loss: 0.5939 - val_accuracy: 0.7602
# Epoch 7/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2757 - accuracy: 0.8788 - val_loss: 0.6668 - val_accuracy: 0.7559
# Epoch 8/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2565 - accuracy: 0.8851 - val_loss: 0.7402 - val_accuracy: 0.7423
# Epoch 9/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2425 - accuracy: 0.8919 - val_loss: 0.7517 - val_accuracy: 0.7464
# Epoch 10/20
# 2000/2000 [==============================] - 9s 4ms/step - loss: 0.2272 - accuracy: 0.8982 - val_loss: 0.8398 - val_accuracy: 0.7474
# Epoch 11/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2137 - accuracy: 0.9003 - val_loss: 0.8843 - val_accuracy: 0.7476
# Epoch 12/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2038 - accuracy: 0.9044 - val_loss: 0.9182 - val_accuracy: 0.7437
# Epoch 13/20
# 2000/2000 [==============================] - 9s 4ms/step - loss: 0.1906 - accuracy: 0.9104 - val_loss: 1.0119 - val_accuracy: 0.7364
# Epoch 14/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1802 - accuracy: 0.9144 - val_loss: 1.0327 - val_accuracy: 0.7446
# Epoch 15/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1705 - accuracy: 0.9175 - val_loss: 1.0989 - val_accuracy: 0.7411
# Epoch 16/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1643 - accuracy: 0.9195 - val_loss: 1.2730 - val_accuracy: 0.7435
# Epoch 17/20
# 2000/2000 [==============================] - 9s 4ms/step - loss: 0.1574 - accuracy: 0.9230 - val_loss: 1.1604 - val_accuracy: 0.7383
# Epoch 18/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1474 - accuracy: 0.9249 - val_loss: 1.3141 - val_accuracy: 0.7341
# Epoch 19/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1422 - accuracy: 0.9277 - val_loss: 1.3815 - val_accuracy: 0.7354
# Epoch 20/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1387 - accuracy: 0.9300 - val_loss: 1.5177 - val_accuracy: 0.7358

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_rnn.history['accuracy'])
plt.plot(history_rnn.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_rnn.history['loss'])
plt.plot(history_rnn.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#Testing on RNN

rnn_loss, rnn_accuracy = rnn_model.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {rnn_accuracy:.4f}')

y_pred = rnn_model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_rnn = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

rnn_model_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {rnn_model_f1:.4f}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.5262 - accuracy: 0.7263
# Test Accuracy: 0.7263
# 313/313 [==============================] - 1s 2ms/step
# F1 Score on Test Set: 0.7236

# %% [markdown]
# # Training and testing on LSTM(Unidirectional)

# %%
uni_LSTM = Sequential()
uni_LSTM.add(Embedding(input_dim=vocab_size, 
                       output_dim=embedding_dim, 
                       weights=[embedding_matrix], 
                       input_length=maxlen, 
                       trainable=False))
uni_LSTM.add(LSTM(10, activation='relu'))  # Unidirectional LSTM layer
uni_LSTM.add(Dense(1, activation='sigmoid'))  

optimizer = Adam(learning_rate=1e-3)
uni_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
uni_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 230, 100)          10018200
#
#  lstm (LSTM)                 (None, 10)                4440
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10022651 (38.23 MB)
# Trainable params: 4451 (17.39 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
#Training the uni_LSTM model 
'''saving the best model while training 
because of the exploding gradiant problem'''

model_checkpoint = ModelCheckpoint(filepath='/kaggle/working/uni_LSTM_best.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True,
                                   mode='min',
                                   verbose=1)

history_uni_LSTM = uni_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16, callbacks=[model_checkpoint])
# Out:
# Epoch 1/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6929 - accuracy: 0.5035
# Epoch 1: val_loss improved from inf to 0.69137, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 99s 49ms/step - loss: 0.6929 - accuracy: 0.5035 - val_loss: 0.6914 - val_accuracy: 0.5115
# Epoch 2/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.9817 - accuracy: 0.5641
# Epoch 2: val_loss improved from 0.69137 to 0.67821, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 97s 49ms/step - loss: 0.9816 - accuracy: 0.5640 - val_loss: 0.6782 - val_accuracy: 0.5791
# Epoch 3/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6767 - accuracy: 0.5767
# Epoch 3: val_loss did not improve from 0.67821
# 2000/2000 [==============================] - 97s 49ms/step - loss: 0.6767 - accuracy: 0.5767 - val_loss: 0.6913 - val_accuracy: 0.5142
# Epoch 4/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6728 - accuracy: 0.5873
# Epoch 4: val_loss improved from 0.67821 to 0.67332, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 98s 49ms/step - loss: 0.6728 - accuracy: 0.5873 - val_loss: 0.6733 - val_accuracy: 0.5865
# Epoch 5/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6666 - accuracy: 0.5999
# Epoch 5: val_loss improved from 0.67332 to 0.66144, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 100s 50ms/step - loss: 0.6666 - accuracy: 0.5999 - val_loss: 0.6614 - val_accuracy: 0.6043
# Epoch 6/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6501 - accuracy: 0.6233
# Epoch 6: val_loss improved from 0.66144 to 0.63321, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 98s 49ms/step - loss: 0.6501 - accuracy: 0.6233 - val_loss: 0.6332 - val_accuracy: 0.6390
# Epoch 7/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5994 - accuracy: 0.6819
# Epoch 7: val_loss improved from 0.63321 to 0.56209, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 97s 49ms/step - loss: 0.5994 - accuracy: 0.6819 - val_loss: 0.5621 - val_accuracy: 0.7211
# Epoch 8/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5506 - accuracy: 0.7264
# Epoch 8: val_loss improved from 0.56209 to 0.52556, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 100s 50ms/step - loss: 0.5506 - accuracy: 0.7264 - val_loss: 0.5256 - val_accuracy: 0.7519
# Epoch 9/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5166 - accuracy: 0.7548
# Epoch 9: val_loss improved from 0.52556 to 0.49973, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 97s 48ms/step - loss: 0.5167 - accuracy: 0.7548 - val_loss: 0.4997 - val_accuracy: 0.7649
# Epoch 10/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.4894 - accuracy: 0.7714
# Epoch 10: val_loss improved from 0.49973 to 0.47458, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 97s 48ms/step - loss: 0.4894 - accuracy: 0.7714 - val_loss: 0.4746 - val_accuracy: 0.7822
# Epoch 11/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 9712.2607 - accuracy: 0.7088
# Epoch 11: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 97s 48ms/step - loss: 9707.4053 - accuracy: 0.7088 - val_loss: 0.6236 - val_accuracy: 0.6564
# Epoch 12/20
# 2000/2000 [==============================] - ETA: 0s - loss: nan - accuracy: 0.5972
# Epoch 12: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 97s 48ms/step - loss: nan - accuracy: 0.5972 - val_loss: nan - val_accuracy: 0.5000
# Epoch 13/20
# 2000/2000 [==============================] - ETA: 0s - loss: nan - accuracy: 0.5012
# Epoch 13: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 96s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000
# Epoch 14/20
# 2000/2000 [==============================] - ETA: 0s - loss: nan - accuracy: 0.5012
# Epoch 14: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 97s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000
# Epoch 15/20
# 2000/2000 [==============================] - ETA: 0s - loss: nan - accuracy: 0.5012
# Epoch 15: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 97s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000
# Epoch 16/20
# 2000/2000 [==============================] - ETA: 0s - loss: nan - accuracy: 0.5012
# Epoch 16: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 96s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000
# Epoch 17/20
# 1999/2000 [============================>.] - ETA: 0s - loss: nan - accuracy: 0.5013
# Epoch 17: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 96s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000
# Epoch 18/20
# 2000/2000 [==============================] - ETA: 0s - loss: nan - accuracy: 0.5012
# Epoch 18: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 97s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000
# Epoch 19/20
# 1999/2000 [============================>.] - ETA: 0s - loss: nan - accuracy: 0.5012
# Epoch 19: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 96s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000
# Epoch 20/20
# 2000/2000 [==============================] - ETA: 0s - loss: nan - accuracy: 0.5012
# Epoch 20: val_loss did not improve from 0.47458
# 2000/2000 [==============================] - 97s 48ms/step - loss: nan - accuracy: 0.5012 - val_loss: nan - val_accuracy: 0.5000

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_uni_LSTM.history['accuracy'])
plt.plot(history_uni_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_uni_LSTM.history['loss'])
plt.plot(history_uni_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing
uni_LSTM = load_model('/kaggle/working/uni_LSTM_best.h5')

uni_loss, uni_accuracy = uni_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {uni_accuracy:.4f}')

y_pred = uni_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_uni_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

uni_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {uni_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 6s 19ms/step - loss: 0.4749 - accuracy: 0.7839
# Test Accuracy: 0.7839
# 313/313 [==============================] - 6s 18ms/step
# F1 Score on Test Set: 0.7827

# %% [markdown]
# # Training and testing on Bi LSTM

# %%
bi_LSTM = Sequential()
bi_LSTM.add(Embedding(input_dim=vocab_size, 
                      output_dim=embedding_dim, 
                      weights=[embedding_matrix], 
                      input_length=maxlen, 
                      trainable=False))
bi_LSTM.add(Bidirectional(LSTM(10, activation='relu')))  # Bidirectional LSTM layer
bi_LSTM.add(Dense(1, activation='sigmoid')) 

optimizer = Adam(learning_rate=1e-3)
bi_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
bi_LSTM.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 230, 100)          10018200
#
#  bidirectional (Bidirection  (None, 20)                8880
#  al)
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 10027101 (38.25 MB)
# Trainable params: 8901 (34.77 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
#Training the bi_LSTM model 
'''saving the best model while training 
because of the exploding gradiant problem'''

model_checkpoint = ModelCheckpoint(filepath='/kaggle/working/bi_LSTM_best.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True,
                                   mode='min',
                                   verbose=1)

history_bi_LSTM = bi_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16, callbacks=[model_checkpoint])
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - ETA: 0s - loss: 6.3406 - accuracy: 0.6147
# Epoch 1: val_loss improved from inf to 0.62206, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 135s 67ms/step - loss: 6.3406 - accuracy: 0.6147 - val_loss: 0.6221 - val_accuracy: 0.6762
# Epoch 2/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6109 - accuracy: 0.6888
# Epoch 2: val_loss improved from 0.62206 to 0.59211, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 133s 67ms/step - loss: 0.6109 - accuracy: 0.6888 - val_loss: 0.5921 - val_accuracy: 0.6982
# Epoch 3/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5791 - accuracy: 0.7021
# Epoch 3: val_loss improved from 0.59211 to 0.56191, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 134s 67ms/step - loss: 0.5791 - accuracy: 0.7021 - val_loss: 0.5619 - val_accuracy: 0.7150
# Epoch 4/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5441 - accuracy: 0.7284
# Epoch 4: val_loss improved from 0.56191 to 0.51729, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 134s 67ms/step - loss: 0.5441 - accuracy: 0.7284 - val_loss: 0.5173 - val_accuracy: 0.7487
# Epoch 5/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.4880 - accuracy: 0.7703
# Epoch 5: val_loss improved from 0.51729 to 0.46227, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 134s 67ms/step - loss: 0.4879 - accuracy: 0.7704 - val_loss: 0.4623 - val_accuracy: 0.7909
# Epoch 6/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4412 - accuracy: 0.7976
# Epoch 6: val_loss improved from 0.46227 to 0.41682, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 134s 67ms/step - loss: 0.4412 - accuracy: 0.7976 - val_loss: 0.4168 - val_accuracy: 0.8123
# Epoch 7/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4409 - accuracy: 0.8160
# Epoch 7: val_loss did not improve from 0.41682
# 2000/2000 [==============================] - 133s 67ms/step - loss: 0.4409 - accuracy: 0.8160 - val_loss: 0.4177 - val_accuracy: 0.8109
# Epoch 8/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8306
# Epoch 8: val_loss improved from 0.41682 to 0.36623, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 134s 67ms/step - loss: 0.3874 - accuracy: 0.8306 - val_loss: 0.3662 - val_accuracy: 0.8413
# Epoch 9/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3732 - accuracy: 0.8370
# Epoch 9: val_loss improved from 0.36623 to 0.36238, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 134s 67ms/step - loss: 0.3732 - accuracy: 0.8370 - val_loss: 0.3624 - val_accuracy: 0.8462
# Epoch 10/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.8465
# Epoch 10: val_loss improved from 0.36238 to 0.35062, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 133s 67ms/step - loss: 0.3541 - accuracy: 0.8465 - val_loss: 0.3506 - val_accuracy: 0.8500
# Epoch 11/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3437 - accuracy: 0.8547
# Epoch 11: val_loss improved from 0.35062 to 0.33596, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 133s 66ms/step - loss: 0.3437 - accuracy: 0.8547 - val_loss: 0.3360 - val_accuracy: 0.8585
# Epoch 12/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3320 - accuracy: 0.8587
# Epoch 12: val_loss improved from 0.33596 to 0.32978, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 135s 68ms/step - loss: 0.3320 - accuracy: 0.8587 - val_loss: 0.3298 - val_accuracy: 0.8586
# Epoch 13/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3230 - accuracy: 0.8640
# Epoch 13: val_loss did not improve from 0.32978
# 2000/2000 [==============================] - 133s 66ms/step - loss: 0.3230 - accuracy: 0.8640 - val_loss: 0.3433 - val_accuracy: 0.8587
# Epoch 14/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3155 - accuracy: 0.8664
# Epoch 14: val_loss did not improve from 0.32978
# 2000/2000 [==============================] - 132s 66ms/step - loss: 0.3155 - accuracy: 0.8664 - val_loss: 0.3300 - val_accuracy: 0.8630
# Epoch 15/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3082 - accuracy: 0.8703
# Epoch 15: val_loss improved from 0.32978 to 0.32693, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 133s 66ms/step - loss: 0.3082 - accuracy: 0.8703 - val_loss: 0.3269 - val_accuracy: 0.8618
# Epoch 16/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.8737
# Epoch 16: val_loss did not improve from 0.32693
# 2000/2000 [==============================] - 132s 66ms/step - loss: 0.3014 - accuracy: 0.8737 - val_loss: 0.3613 - val_accuracy: 0.8511
# Epoch 17/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2968 - accuracy: 0.8755
# Epoch 17: val_loss improved from 0.32693 to 0.31831, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 133s 66ms/step - loss: 0.2968 - accuracy: 0.8755 - val_loss: 0.3183 - val_accuracy: 0.8668
# Epoch 18/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.8799
# Epoch 18: val_loss did not improve from 0.31831
# 2000/2000 [==============================] - 134s 67ms/step - loss: 0.2909 - accuracy: 0.8799 - val_loss: 0.3383 - val_accuracy: 0.8662
# Epoch 19/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.2860 - accuracy: 0.8812
# Epoch 19: val_loss did not improve from 0.31831
# 2000/2000 [==============================] - 132s 66ms/step - loss: 0.2859 - accuracy: 0.8812 - val_loss: 0.3309 - val_accuracy: 0.8583
# Epoch 20/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2804 - accuracy: 0.8823
# Epoch 20: val_loss did not improve from 0.31831
# 2000/2000 [==============================] - 133s 67ms/step - loss: 0.2804 - accuracy: 0.8823 - val_loss: 0.3211 - val_accuracy: 0.8633

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_bi_LSTM.history['accuracy'])
plt.plot(history_bi_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_bi_LSTM.history['loss'])
plt.plot(history_bi_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing
bi_LSTM = load_model('/kaggle/working/bi_LSTM_best.h5')

bi_loss, bi_accuracy = bi_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {bi_accuracy:.4f}')

y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)

f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {f1:.4f}')
# Out:
# 313/313 [==============================] - 7s 22ms/step - loss: 0.3198 - accuracy: 0.8663
# Test Accuracy: 0.8663
# 313/313 [==============================] - 7s 21ms/step
# F1 Score on Test Set: 0.8671

# %%
y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_bi_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

bi_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {bi_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 7s 21ms/step
# F1 Score on Test Set: 0.8671

# %% [markdown]
# # Visualizing the results

# %%
# All test metrics at a glance

data = {
    'Model': ['RNN', 'Uni-LSTM', 'Bi-LSTM'],
    'Accuracy': [rnn_accuracy, uni_accuracy, bi_accuracy],
    'F1 Score': [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1],
    'Loss': [rnn_loss, uni_loss, bi_loss]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Model  Accuracy  F1 Score      Loss
# 0       RNN    0.7263  0.723619  1.526186
# 1  Uni-LSTM    0.7839  0.782705  0.474932
# 2   Bi-LSTM    0.8663  0.867137  0.319812

# %% [markdown]
# **Training accuracy and loss**

# %%
# Extracting information from history objects
epochs = range(1, len(history_rnn.history['accuracy']) + 1)

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, history_rnn.history['accuracy'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['accuracy'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['accuracy'], label='Bi-LSTM', marker='o')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, history_rnn.history['loss'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['loss'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['loss'], label='Bi-LSTM', marker='o')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization/Comparison with Bar charts**

# %%
# Data
accuracy_data = [rnn_accuracy, uni_accuracy, bi_accuracy]
f1_data = [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1]
loss_data = [rnn_loss, uni_loss, bi_loss]
models = ['RNN', 'LSTM', 'Bi-LSTM']

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.bar(models, accuracy_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Accuracy')
plt.ylabel('Accuracy')

# Plotting f1
plt.subplot(1, 3, 2)
plt.bar(models, f1_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test F1')
plt.ylabel('F1 Score')


# Plotting Loss
plt.subplot(1, 3, 3)
plt.bar(models, loss_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Loss')
plt.ylabel('Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Overall performance visualization with heatmaps**

# %%
cms = [cm_rnn, cm_uni_LSTM, cm_bi_LSTM]
model_names = ['rnn', 'uni_LSTM', 'bi_LSTM']

plt.figure(figsize=(18, 6))

for i, cm in enumerate(cms, 1):
    plt.subplot(1, 3, i)
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlGnBu', 
                xticklabels=['Predicted Negative', 'Predicted Positive'],
                yticklabels=['Actual Negative', 'Actual Positive'])
    plt.title(f'Confusion Matrix - {model_names[i-1]}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

plt.tight_layout()
plt.show()
