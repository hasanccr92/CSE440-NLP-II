# %% [markdown]
# # **This notebook is prepared as a project for the reqirement of the course CSE440-Natural Language Processing II of Brac University.**

# %% [markdown]
# **In this notebook, we have used 3 different approaches for sentiment classification on a customized IMDB Dataset. Workflow--->**
# * **Importing/installing necessary libraries**
# * **EDA**
# * **Text Data Preprocessing**
# * **Loading a Pre-trained vector and making an Embedding matrix**
# * **RNN Training and testing**
# * **LSTM Training and testing**
# * **BiLSTM Training and testing**
# * **Result Visualization**

# %% [markdown]
# # Importing/installing necessary libraries

# %%
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')

import matplotlib.pyplot as plt
import seaborn as sns

import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, Dense
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.optimizers import Adam

import os
import warnings

warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Creating a dynamic data path**

# %%
'''input the path of the directory 
containing both files '''

dir = '/kaggle/input/'  

for dirname, _, filenames in os.walk(dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        if filename.endswith('.txt'):
            vecPath = os.path.join(dirname, filename)
        else:
            dataPath = os.path.join(dirname, filename)
# Out:
# /kaggle/input/imdb-for-440-project/glove.6B.100d.txt
# /kaggle/input/imdb-for-440-project/imdb_440/IMDB Dataset.csv

# %% [markdown]
# # EDA

# %%
df = pd.read_csv(dataPath)
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(df.dtypes)

# Check for missing values
print(df.isnull().sum())
# Out:
# review       object
# sentiment    object
# dtype: object
# review       0
# sentiment    0
# dtype: int64

# %%
df.sentiment.unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
#data distribution
#balance check

sentiment_distribution = df['sentiment'].value_counts()

# Plotting the distribution
plt.bar(sentiment_distribution.index, sentiment_distribution.values, color=['red', 'green'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ![rsz_thanos-perfectly-balanced-as-all-things-should-be.jpg](attachment:3ff44880-3019-4245-a7be-71c8625ced4b.jpg)

# %%
# Calculate text lengths
df['text_length'] = df['review'].apply(len)

# Plot histogram
plt.figure(figsize=(5, 3))
plt.hist(df['text_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# Tokenize the text
df['token_length'] = df['review'].apply(lambda x: len(word_tokenize(x)))

# Plot histogram 
plt.figure(figsize=(5, 3))
plt.hist(df['token_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Token Lengths')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Preprocessing the text data

# %%
# binary encode sentiments
encoder = LabelEncoder()
df['sentiment'] = encoder.fit_transform(df['sentiment'])

def preprocess_text(text):
    #html tag handling
    text = re.sub(r'<[^>]+>', '', text)

    # Lowercasing
    text = text.lower()

    # Tokenization
    tokens = word_tokenize(text)

    #punctuation and stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]

#     stemmer = PorterStemmer()
#     tokens = [stemmer.stem(word) for word in tokens]

    return ' '.join(tokens)
df['cleaned_review'] = df['review'].apply(preprocess_text)

# Compare the two
print(df[['review', 'cleaned_review']].head())
# Out:
#                                               review  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...
#
#                                       cleaned_review
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically family little boy jake thinks zombie...
# 4  petter mattei love time money visually stunnin...

# %% [markdown]
# # Loading GloVe and making an Embedding Matrix

# %%
def load_glove_vectors(glovePath):
    embedding_index = {}
    with open(glovePath, 'r', encoding='utf8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embedding_index[word] = coefs
    return embedding_index

# Load GloVe Vectors
glove_vectors = load_glove_vectors(vecPath)

# Tokenize, text ---> sequences
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['cleaned_review'])  
sequences = tokenizer.texts_to_sequences(df['cleaned_review'])

# Create an embedding matrix
embedding_dim = 100
vocab_size = len(tokenizer.word_index) + 1
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in tokenizer.word_index.items():
    embedding_vector = glove_vectors.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# **Train-test split and padding**

# %%
X = sequences  
y = df['sentiment'].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Padding sequences
maxlen = 150  # Maximum length of all sequences
X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %% [markdown]
# # Training and testing on RNN

# %%
# Building the model
rnn_model = Sequential()
rnn_model.add(Embedding(input_dim=vocab_size, 
                    output_dim=embedding_dim, 
                    weights=[embedding_matrix], 
                    input_length=maxlen, 
                    trainable=False))
rnn_model.add(Flatten())  # Flatten the output of the embedding layer
rnn_model.add(Dense(10, activation='relu'))
rnn_model.add(Dense(1, activation='sigmoid'))  

# optimizer = Adam(learning_rate=1e-3)
rnn_model.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])

rnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 100)          10018200
#
#  flatten (Flatten)           (None, 15000)             0
#
#  dense (Dense)               (None, 10)                150010
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10168221 (38.79 MB)
# Trainable params: 150021 (586.02 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
# Training the model

history_rnn = rnn_model.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.5444 - accuracy: 0.7268 - val_loss: 0.4870 - val_accuracy: 0.7704
# Epoch 2/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.4214 - accuracy: 0.8068 - val_loss: 0.4918 - val_accuracy: 0.7688
# Epoch 3/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.3628 - accuracy: 0.8378 - val_loss: 0.5054 - val_accuracy: 0.7635
# Epoch 4/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.3170 - accuracy: 0.8591 - val_loss: 0.5554 - val_accuracy: 0.7575
# Epoch 5/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2838 - accuracy: 0.8747 - val_loss: 0.6018 - val_accuracy: 0.7450
# Epoch 6/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2526 - accuracy: 0.8880 - val_loss: 0.6989 - val_accuracy: 0.7506
# Epoch 7/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2260 - accuracy: 0.8981 - val_loss: 0.6951 - val_accuracy: 0.7394
# Epoch 8/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.2028 - accuracy: 0.9058 - val_loss: 0.9236 - val_accuracy: 0.7430
# Epoch 9/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1824 - accuracy: 0.9141 - val_loss: 0.9577 - val_accuracy: 0.7301
# Epoch 10/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.1649 - accuracy: 0.9213 - val_loss: 1.0391 - val_accuracy: 0.7335
# Epoch 11/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.1561 - accuracy: 0.9249 - val_loss: 0.9960 - val_accuracy: 0.7296
# Epoch 12/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.1441 - accuracy: 0.9297 - val_loss: 1.2342 - val_accuracy: 0.7351
# Epoch 13/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.1303 - accuracy: 0.9343 - val_loss: 1.3893 - val_accuracy: 0.7337
# Epoch 14/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1260 - accuracy: 0.9359 - val_loss: 1.3673 - val_accuracy: 0.7301
# Epoch 15/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1243 - accuracy: 0.9367 - val_loss: 1.3735 - val_accuracy: 0.7319
# Epoch 16/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1177 - accuracy: 0.9390 - val_loss: 1.5531 - val_accuracy: 0.7320
# Epoch 17/20
# 2000/2000 [==============================] - 7s 3ms/step - loss: 0.1093 - accuracy: 0.9427 - val_loss: 1.6705 - val_accuracy: 0.7356
# Epoch 18/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.1105 - accuracy: 0.9426 - val_loss: 1.6596 - val_accuracy: 0.7274
# Epoch 19/20
# 2000/2000 [==============================] - 7s 4ms/step - loss: 0.1060 - accuracy: 0.9439 - val_loss: 1.7679 - val_accuracy: 0.7341
# Epoch 20/20
# 2000/2000 [==============================] - 8s 4ms/step - loss: 0.1013 - accuracy: 0.9460 - val_loss: 1.7542 - val_accuracy: 0.7295

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_rnn.history['accuracy'])
plt.plot(history_rnn.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_rnn.history['loss'])
plt.plot(history_rnn.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#Testing on RNN

rnn_loss, rnn_accuracy = rnn_model.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {rnn_accuracy:.4f}')

y_pred = rnn_model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_rnn = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

rnn_model_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {rnn_model_f1:.4f}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.8472 - accuracy: 0.7183
# Test Accuracy: 0.7183
# 313/313 [==============================] - 1s 2ms/step
# F1 Score on Test Set: 0.7103

# %% [markdown]
# # Training and testing on LSTM(Unidirectional)

# %%
uni_LSTM = Sequential()
uni_LSTM.add(Embedding(input_dim=vocab_size, 
                       output_dim=embedding_dim, 
                       weights=[embedding_matrix], 
                       input_length=maxlen, 
                       trainable=False))
uni_LSTM.add(LSTM(10, activation='relu'))  # Unidirectional LSTM layer
uni_LSTM.add(Dense(1, activation='sigmoid'))  

optimizer = Adam(learning_rate=1e-3)
uni_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
uni_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 150, 100)          10018200
#
#  lstm (LSTM)                 (None, 10)                4440
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10022651 (38.23 MB)
# Trainable params: 4451 (17.39 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
#Training the uni_LSTM model 
'''saving the best model while training 
because of the exploding gradiant problem'''

model_checkpoint = ModelCheckpoint(filepath='/kaggle/working/uni_LSTM_best.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True,
                                   mode='min',
                                   verbose=1)

history_uni_LSTM = uni_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16, callbacks=[model_checkpoint])
# Out:
# Epoch 1/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.7487 - accuracy: 0.5196
# Epoch 1: val_loss improved from inf to 0.68488, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 64s 31ms/step - loss: 0.7487 - accuracy: 0.5196 - val_loss: 0.6849 - val_accuracy: 0.5259
# Epoch 2/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6829 - accuracy: 0.5296
# Epoch 2: val_loss improved from 0.68488 to 0.68134, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 31ms/step - loss: 0.6829 - accuracy: 0.5296 - val_loss: 0.6813 - val_accuracy: 0.5344
# Epoch 3/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6805 - accuracy: 0.5339
# Epoch 3: val_loss improved from 0.68134 to 0.67863, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 31ms/step - loss: 0.6805 - accuracy: 0.5338 - val_loss: 0.6786 - val_accuracy: 0.5378
# Epoch 4/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6783 - accuracy: 0.5363
# Epoch 4: val_loss improved from 0.67863 to 0.67858, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 31ms/step - loss: 0.6783 - accuracy: 0.5364 - val_loss: 0.6786 - val_accuracy: 0.5431
# Epoch 5/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6766 - accuracy: 0.5327
# Epoch 5: val_loss improved from 0.67858 to 0.67564, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 31ms/step - loss: 0.6766 - accuracy: 0.5327 - val_loss: 0.6756 - val_accuracy: 0.5411
# Epoch 6/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6836 - accuracy: 0.5327
# Epoch 6: val_loss did not improve from 0.67564
# 2000/2000 [==============================] - 63s 32ms/step - loss: 0.6837 - accuracy: 0.5327 - val_loss: 0.6768 - val_accuracy: 0.5384
# Epoch 7/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6732 - accuracy: 0.5427
# Epoch 7: val_loss improved from 0.67564 to 0.67039, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 31ms/step - loss: 0.6732 - accuracy: 0.5427 - val_loss: 0.6704 - val_accuracy: 0.5425
# Epoch 8/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.6630 - accuracy: 0.5587
# Epoch 8: val_loss improved from 0.67039 to 0.64850, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 32ms/step - loss: 0.6630 - accuracy: 0.5587 - val_loss: 0.6485 - val_accuracy: 0.6022
# Epoch 9/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.6618 - accuracy: 0.5618
# Epoch 9: val_loss did not improve from 0.64850
# 2000/2000 [==============================] - 63s 31ms/step - loss: 0.6617 - accuracy: 0.5618 - val_loss: 0.6565 - val_accuracy: 0.5550
# Epoch 10/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5812 - accuracy: 0.6941
# Epoch 10: val_loss improved from 0.64850 to 0.45768, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 31ms/step - loss: 0.5810 - accuracy: 0.6942 - val_loss: 0.4577 - val_accuracy: 0.8066
# Epoch 11/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.4604 - accuracy: 0.7996
# Epoch 11: val_loss improved from 0.45768 to 0.43727, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 63s 32ms/step - loss: 0.4604 - accuracy: 0.7996 - val_loss: 0.4373 - val_accuracy: 0.8171
# Epoch 12/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.4200 - accuracy: 0.8058
# Epoch 12: val_loss improved from 0.43727 to 0.39495, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.4199 - accuracy: 0.8059 - val_loss: 0.3950 - val_accuracy: 0.8231
# Epoch 13/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8210
# Epoch 13: val_loss improved from 0.39495 to 0.39370, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.4020 - accuracy: 0.8210 - val_loss: 0.3937 - val_accuracy: 0.8246
# Epoch 14/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3836 - accuracy: 0.8329
# Epoch 14: val_loss improved from 0.39370 to 0.36986, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.3836 - accuracy: 0.8329 - val_loss: 0.3699 - val_accuracy: 0.8453
# Epoch 15/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3866 - accuracy: 0.8294
# Epoch 15: val_loss improved from 0.36986 to 0.36240, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.3867 - accuracy: 0.8293 - val_loss: 0.3624 - val_accuracy: 0.8396
# Epoch 16/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3671 - accuracy: 0.8422
# Epoch 16: val_loss did not improve from 0.36240
# 2000/2000 [==============================] - 63s 32ms/step - loss: 0.3671 - accuracy: 0.8422 - val_loss: 0.4056 - val_accuracy: 0.8189
# Epoch 17/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3603 - accuracy: 0.8448
# Epoch 17: val_loss improved from 0.36240 to 0.34881, saving model to /kaggle/working/uni_LSTM_best.h5
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.3602 - accuracy: 0.8448 - val_loss: 0.3488 - val_accuracy: 0.8469
# Epoch 18/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3997 - accuracy: 0.8258
# Epoch 18: val_loss did not improve from 0.34881
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.3997 - accuracy: 0.8258 - val_loss: 1.2960 - val_accuracy: 0.5353
# Epoch 19/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5749 - accuracy: 0.6943
# Epoch 19: val_loss did not improve from 0.34881
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.5749 - accuracy: 0.6943 - val_loss: 0.4313 - val_accuracy: 0.7933
# Epoch 20/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3770 - accuracy: 0.8298
# Epoch 20: val_loss did not improve from 0.34881
# 2000/2000 [==============================] - 64s 32ms/step - loss: 0.3769 - accuracy: 0.8298 - val_loss: 0.3663 - val_accuracy: 0.8397

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_uni_LSTM.history['accuracy'])
plt.plot(history_uni_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_uni_LSTM.history['loss'])
plt.plot(history_uni_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing
uni_LSTM = load_model('/kaggle/working/uni_LSTM_best.h5')

uni_loss, uni_accuracy = uni_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {uni_accuracy:.4f}')

y_pred = uni_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_uni_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

uni_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {uni_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 4s 13ms/step - loss: 0.3531 - accuracy: 0.8444
# Test Accuracy: 0.8444
# 313/313 [==============================] - 4s 13ms/step
# F1 Score on Test Set: 0.8394

# %% [markdown]
# # Training and testing on Bi LSTM

# %%
bi_LSTM = Sequential()
bi_LSTM.add(Embedding(input_dim=vocab_size, 
                      output_dim=embedding_dim, 
                      weights=[embedding_matrix], 
                      input_length=maxlen, 
                      trainable=False))
bi_LSTM.add(Bidirectional(LSTM(10, activation='relu')))  # Bidirectional LSTM layer
bi_LSTM.add(Dense(1, activation='sigmoid')) 

optimizer = Adam(learning_rate=1e-3)
bi_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
bi_LSTM.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 150, 100)          10018200
#
#  bidirectional (Bidirection  (None, 20)                8880
#  al)
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 10027101 (38.25 MB)
# Trainable params: 8901 (34.77 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
#Training the bi_LSTM model 
'''saving the best model while training 
because of the exploding gradiant problem'''

model_checkpoint = ModelCheckpoint(filepath='/kaggle/working/bi_LSTM_best.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True,
                                   mode='min',
                                   verbose=1)

history_bi_LSTM = bi_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16, callbacks=[model_checkpoint])
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - ETA: 0s - loss: 17.1631 - accuracy: 0.6556
# Epoch 1: val_loss improved from inf to 0.59969, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 93s 45ms/step - loss: 17.1631 - accuracy: 0.6556 - val_loss: 0.5997 - val_accuracy: 0.6790
# Epoch 2/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5955 - accuracy: 0.6849
# Epoch 2: val_loss improved from 0.59969 to 0.59228, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.5955 - accuracy: 0.6849 - val_loss: 0.5923 - val_accuracy: 0.6824
# Epoch 3/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5902 - accuracy: 0.6875
# Epoch 3: val_loss improved from 0.59228 to 0.58669, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.5902 - accuracy: 0.6875 - val_loss: 0.5867 - val_accuracy: 0.6851
# Epoch 4/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5830 - accuracy: 0.6931
# Epoch 4: val_loss improved from 0.58669 to 0.57312, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.5830 - accuracy: 0.6931 - val_loss: 0.5731 - val_accuracy: 0.6926
# Epoch 5/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.5504 - accuracy: 0.7205
# Epoch 5: val_loss improved from 0.57312 to 0.48808, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.5504 - accuracy: 0.7206 - val_loss: 0.4881 - val_accuracy: 0.7669
# Epoch 6/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.4516 - accuracy: 0.7924
# Epoch 6: val_loss improved from 0.48808 to 0.42103, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.4516 - accuracy: 0.7923 - val_loss: 0.4210 - val_accuracy: 0.8126
# Epoch 7/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4123 - accuracy: 0.8157
# Epoch 7: val_loss improved from 0.42103 to 0.39195, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 91s 45ms/step - loss: 0.4123 - accuracy: 0.8157 - val_loss: 0.3919 - val_accuracy: 0.8304
# Epoch 8/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.8260
# Epoch 8: val_loss improved from 0.39195 to 0.37943, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.3895 - accuracy: 0.8260 - val_loss: 0.3794 - val_accuracy: 0.8359
# Epoch 9/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3688 - accuracy: 0.8355
# Epoch 9: val_loss improved from 0.37943 to 0.35688, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 95s 48ms/step - loss: 0.3690 - accuracy: 0.8354 - val_loss: 0.3569 - val_accuracy: 0.8451
# Epoch 10/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3539 - accuracy: 0.8444
# Epoch 10: val_loss improved from 0.35688 to 0.35424, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 91s 45ms/step - loss: 0.3539 - accuracy: 0.8444 - val_loss: 0.3542 - val_accuracy: 0.8450
# Epoch 11/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3390 - accuracy: 0.8525
# Epoch 11: val_loss improved from 0.35424 to 0.33479, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.3390 - accuracy: 0.8525 - val_loss: 0.3348 - val_accuracy: 0.8574
# Epoch 12/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3260 - accuracy: 0.8585
# Epoch 12: val_loss improved from 0.33479 to 0.33111, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 91s 46ms/step - loss: 0.3259 - accuracy: 0.8585 - val_loss: 0.3311 - val_accuracy: 0.8579
# Epoch 13/20
# 2000/2000 [==============================] - ETA: 0s - loss: 401.5199 - accuracy: 0.8636
# Epoch 13: val_loss improved from 0.33111 to 0.32283, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 401.5199 - accuracy: 0.8636 - val_loss: 0.3228 - val_accuracy: 0.8629
# Epoch 14/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3101 - accuracy: 0.8667
# Epoch 14: val_loss did not improve from 0.32283
# 2000/2000 [==============================] - 91s 45ms/step - loss: 0.3101 - accuracy: 0.8668 - val_loss: 0.3434 - val_accuracy: 0.8550
# Epoch 15/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.3045 - accuracy: 0.8705
# Epoch 15: val_loss did not improve from 0.32283
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.3046 - accuracy: 0.8704 - val_loss: 0.3444 - val_accuracy: 0.8534
# Epoch 16/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.2964 - accuracy: 0.8740
# Epoch 16: val_loss improved from 0.32283 to 0.31629, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.2963 - accuracy: 0.8741 - val_loss: 0.3163 - val_accuracy: 0.8671
# Epoch 17/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2914 - accuracy: 0.8770
# Epoch 17: val_loss did not improve from 0.31629
# 2000/2000 [==============================] - 91s 45ms/step - loss: 0.2914 - accuracy: 0.8770 - val_loss: 0.3186 - val_accuracy: 0.8646
# Epoch 18/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.2878 - accuracy: 0.8782
# Epoch 18: val_loss improved from 0.31629 to 0.31547, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 91s 45ms/step - loss: 0.2878 - accuracy: 0.8782 - val_loss: 0.3155 - val_accuracy: 0.8679
# Epoch 19/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.8830
# Epoch 19: val_loss did not improve from 0.31547
# 2000/2000 [==============================] - 91s 45ms/step - loss: 0.2800 - accuracy: 0.8830 - val_loss: 0.3317 - val_accuracy: 0.8585
# Epoch 20/20
# 1999/2000 [============================>.] - ETA: 0s - loss: 0.2772 - accuracy: 0.8833
# Epoch 20: val_loss improved from 0.31547 to 0.31363, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 90s 45ms/step - loss: 0.2772 - accuracy: 0.8833 - val_loss: 0.3136 - val_accuracy: 0.8681

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_bi_LSTM.history['accuracy'])
plt.plot(history_bi_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_bi_LSTM.history['loss'])
plt.plot(history_bi_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing
bi_LSTM = load_model('/kaggle/working/bi_LSTM_best.h5')

bi_loss, bi_accuracy = bi_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {bi_accuracy:.4f}')

y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)

f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {f1:.4f}')
# Out:
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3200 - accuracy: 0.8604
# Test Accuracy: 0.8604
# 313/313 [==============================] - 5s 15ms/step
# F1 Score on Test Set: 0.8636

# %%
y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_bi_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

bi_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {bi_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 5s 15ms/step
# F1 Score on Test Set: 0.8636

# %% [markdown]
# # Visualizing the results

# %%
# All test metrics at a glance

data = {
    'Model': ['RNN', 'Uni-LSTM', 'Bi-LSTM'],
    'Accuracy': [rnn_accuracy, uni_accuracy, bi_accuracy],
    'F1 Score': [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1],
    'Loss': [rnn_loss, uni_loss, bi_loss]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Model  Accuracy  F1 Score      Loss
# 0       RNN    0.7183  0.710334  1.847245
# 1  Uni-LSTM    0.8444  0.839356  0.353081
# 2   Bi-LSTM    0.8604  0.863619  0.319968

# %% [markdown]
# **Training accuracy and loss**

# %%
# Extracting information from history objects
epochs = range(1, len(history_rnn.history['accuracy']) + 1)

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, history_rnn.history['accuracy'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['accuracy'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['accuracy'], label='Bi-LSTM', marker='o')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, history_rnn.history['loss'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['loss'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['loss'], label='Bi-LSTM', marker='o')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization/Comparison with Bar charts**

# %%
# Data
accuracy_data = [rnn_accuracy, uni_accuracy, bi_accuracy]
f1_data = [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1]
loss_data = [rnn_loss, uni_loss, bi_loss]
models = ['RNN', 'LSTM', 'Bi-LSTM']

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.bar(models, accuracy_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Accuracy')
plt.ylabel('Accuracy')

# Plotting f1
plt.subplot(1, 3, 2)
plt.bar(models, f1_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test F1')
plt.ylabel('F1 Score')


# Plotting Loss
plt.subplot(1, 3, 3)
plt.bar(models, loss_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Loss')
plt.ylabel('Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Overall performance visualization with heatmaps**

# %%
cms = [cm_rnn, cm_uni_LSTM, cm_bi_LSTM]
model_names = ['rnn', 'uni_LSTM', 'bi_LSTM']

plt.figure(figsize=(18, 6))

for i, cm in enumerate(cms, 1):
    plt.subplot(1, 3, i)
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlGnBu', 
                xticklabels=['Predicted Negative', 'Predicted Positive'],
                yticklabels=['Actual Negative', 'Actual Positive'])
    plt.title(f'Confusion Matrix - {model_names[i-1]}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

plt.tight_layout()
plt.show()
