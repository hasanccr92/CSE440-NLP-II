# %% [markdown]
# # **This notebook is prepared as a project for the reqirement of the course CSE440-Natural Language Processing II of Brac University.**

# %% [markdown]
# **In this notebook, we have used 3 different approaches for sentiment classification on a customized IMDB Dataset. Workflow--->**
# * **Importing/installing necessary libraries**
# * **EDA**
# * **Text Data Preprocessing**
# * **Loading a Pre-trained vector and making an Embedding matrix**
# * **RNN Training and testing**
# * **LSTM Training and testing**
# * **BiLSTM Training and testing**
# * **Result Visualization**

# %% [markdown]
# # Importing/installing necessary libraries

# %%
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')

import matplotlib.pyplot as plt
import seaborn as sns

import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, Dense
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import Bidirectional
from tensorflow.keras.optimizers import Adam

import os
import warnings

warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Creating a dynamic data path**

# %%
'''input the path of the directory 
containing both files '''

dir = '/kaggle/input/'  

for dirname, _, filenames in os.walk(dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        if filename.endswith('.txt'):
            vecPath = os.path.join(dirname, filename)
        else:
            dataPath = os.path.join(dirname, filename)
# Out:
# /kaggle/input/imdb-for-440-project/glove.6B.100d.txt
# /kaggle/input/imdb-for-440-project/imdb_440/IMDB Dataset.csv

# %% [markdown]
# # EDA

# %%
df = pd.read_csv(dataPath)
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(df.dtypes)

# Check for missing values
print(df.isnull().sum())
# Out:
# review       object
# sentiment    object
# dtype: object
# review       0
# sentiment    0
# dtype: int64

# %%
df.sentiment.unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
#data distribution
#balance check

sentiment_distribution = df['sentiment'].value_counts()

# Plotting the distribution
plt.bar(sentiment_distribution.index, sentiment_distribution.values, color=['red', 'green'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ![rsz_thanos-perfectly-balanced-as-all-things-should-be.jpg](attachment:3ff44880-3019-4245-a7be-71c8625ced4b.jpg)

# %%
# Calculate text lengths
df['text_length'] = df['review'].apply(len)

# Plot histogram
plt.figure(figsize=(5, 3))
plt.hist(df['text_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# Tokenize the text
df['token_length'] = df['review'].apply(lambda x: len(word_tokenize(x)))

# Plot histogram 
plt.figure(figsize=(5, 3))
plt.hist(df['token_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Token Lengths')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Preprocessing the text data

# %%
# binary encode sentiments
encoder = LabelEncoder()
df['sentiment'] = encoder.fit_transform(df['sentiment'])

def preprocess_text(text):
    #html tag handling
    text = re.sub(r'<[^>]+>', '', text)

    # Lowercasing
    text = text.lower()

    # Tokenization
    tokens = word_tokenize(text)

    #punctuation and stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]

#     stemmer = PorterStemmer()
#     tokens = [stemmer.stem(word) for word in tokens]

    return ' '.join(tokens)
df['cleaned_review'] = df['review'].apply(preprocess_text)

# Compare the two
print(df[['review', 'cleaned_review']].head())
# Out:
#                                               review  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...
#
#                                       cleaned_review
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically family little boy jake thinks zombie...
# 4  petter mattei love time money visually stunnin...

# %% [markdown]
# # Loading GloVe and making an Embedding Matrix

# %%
def load_glove_vectors(glovePath):
    embedding_index = {}
    with open(glovePath, 'r', encoding='utf8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embedding_index[word] = coefs
    return embedding_index

# Load GloVe Vectors
glove_vectors = load_glove_vectors(vecPath)

# Tokenize, text ---> sequences
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['cleaned_review'])  
sequences = tokenizer.texts_to_sequences(df['cleaned_review'])

# Create an embedding matrix
embedding_dim = 100
vocab_size = len(tokenizer.word_index) + 1
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in tokenizer.word_index.items():
    embedding_vector = glove_vectors.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# **Train-test split and padding**

# %%
X = sequences  
y = df['sentiment'].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Padding sequences
maxlen = 256  # Maximum length of all sequences
X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %% [markdown]
# # Training and testing on RNN

# %%
# Building the model
rnn_model = Sequential()
rnn_model.add(Embedding(input_dim=vocab_size, 
                    output_dim=embedding_dim, 
                    weights=[embedding_matrix], 
                    input_length=maxlen, 
                    trainable=False))
rnn_model.add(Flatten())  # Flatten the output of the embedding layer
rnn_model.add(Dense(10, activation='relu'))
rnn_model.add(Dense(1, activation='sigmoid'))  

# optimizer = Adam(learning_rate=1e-3)
rnn_model.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])

rnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 256, 100)          10018200
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense (Dense)               (None, 10)                256010
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10274221 (39.19 MB)
# Trainable params: 256021 (1000.08 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
# Training the model

history_rnn = rnn_model.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 9s 3ms/step - loss: 0.6252 - accuracy: 0.6527 - val_loss: 0.5790 - val_accuracy: 0.7336
# Epoch 2/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.4956 - accuracy: 0.7771 - val_loss: 0.5233 - val_accuracy: 0.7569
# Epoch 3/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.4268 - accuracy: 0.8152 - val_loss: 0.5363 - val_accuracy: 0.7654
# Epoch 4/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.3850 - accuracy: 0.8394 - val_loss: 0.5685 - val_accuracy: 0.7649
# Epoch 5/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.3527 - accuracy: 0.8543 - val_loss: 0.5644 - val_accuracy: 0.7536
# Epoch 6/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.3212 - accuracy: 0.8712 - val_loss: 0.6211 - val_accuracy: 0.7576
# Epoch 7/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.2965 - accuracy: 0.8830 - val_loss: 0.7052 - val_accuracy: 0.7544
# Epoch 8/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.2741 - accuracy: 0.8947 - val_loss: 0.6495 - val_accuracy: 0.7415
# Epoch 9/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.2585 - accuracy: 0.9017 - val_loss: 0.7383 - val_accuracy: 0.7499
# Epoch 10/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.2394 - accuracy: 0.9111 - val_loss: 0.7552 - val_accuracy: 0.7440
# Epoch 11/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.2277 - accuracy: 0.9157 - val_loss: 0.8062 - val_accuracy: 0.7489
# Epoch 12/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.2152 - accuracy: 0.9210 - val_loss: 0.9230 - val_accuracy: 0.7441
# Epoch 13/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.2089 - accuracy: 0.9236 - val_loss: 0.8704 - val_accuracy: 0.7330
# Epoch 14/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1995 - accuracy: 0.9281 - val_loss: 1.1161 - val_accuracy: 0.7464
# Epoch 15/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1944 - accuracy: 0.9298 - val_loss: 1.1067 - val_accuracy: 0.7439
# Epoch 16/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1838 - accuracy: 0.9343 - val_loss: 1.1024 - val_accuracy: 0.7396
# Epoch 17/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1819 - accuracy: 0.9365 - val_loss: 1.1677 - val_accuracy: 0.7420
# Epoch 18/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1745 - accuracy: 0.9398 - val_loss: 1.3161 - val_accuracy: 0.7436
# Epoch 19/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.1736 - accuracy: 0.9394 - val_loss: 1.2290 - val_accuracy: 0.7312
# Epoch 20/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1664 - accuracy: 0.9426 - val_loss: 1.2824 - val_accuracy: 0.7346

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_rnn.history['accuracy'])
plt.plot(history_rnn.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_rnn.history['loss'])
plt.plot(history_rnn.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#Testing on RNN

rnn_loss, rnn_accuracy = rnn_model.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {rnn_accuracy:.4f}')

y_pred = rnn_model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_rnn = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

rnn_model_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {rnn_model_f1:.4f}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.3754 - accuracy: 0.7231
# Test Accuracy: 0.7231
# 313/313 [==============================] - 1s 1ms/step
# F1 Score on Test Set: 0.7326

# %% [markdown]
# # Training and testing on LSTM(Unidirectional)

# %%
uni_LSTM = Sequential()
uni_LSTM.add(Embedding(input_dim=vocab_size, 
                       output_dim=embedding_dim, 
                       weights=[embedding_matrix], 
                       input_length=maxlen, 
                       trainable=False))
uni_LSTM.add(LSTM(10))  # Unidirectional LSTM layer
uni_LSTM.add(Dense(1, activation='sigmoid'))  

optimizer = Adam(learning_rate=1e-3)
uni_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
uni_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 256, 100)          10018200
#
#  lstm (LSTM)                 (None, 10)                4440
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10022651 (38.23 MB)
# Trainable params: 4451 (17.39 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
# Training the uni_LSTM model

history_uni_LSTM = uni_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 21s 9ms/step - loss: 0.6914 - accuracy: 0.5076 - val_loss: 0.6866 - val_accuracy: 0.5161
# Epoch 2/20
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.6918 - accuracy: 0.5058 - val_loss: 0.6931 - val_accuracy: 0.4984
# Epoch 3/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.6905 - accuracy: 0.5096 - val_loss: 0.6851 - val_accuracy: 0.5200
# Epoch 4/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.6046 - accuracy: 0.6779 - val_loss: 0.5494 - val_accuracy: 0.7613
# Epoch 5/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5831 - accuracy: 0.7233 - val_loss: 0.6140 - val_accuracy: 0.6899
# Epoch 6/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5628 - accuracy: 0.7445 - val_loss: 0.5401 - val_accuracy: 0.7690
# Epoch 7/20
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.5395 - accuracy: 0.7676 - val_loss: 0.5277 - val_accuracy: 0.7781
# Epoch 8/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5822 - accuracy: 0.6953 - val_loss: 0.5382 - val_accuracy: 0.7734
# Epoch 9/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5668 - accuracy: 0.7224 - val_loss: 0.6771 - val_accuracy: 0.5370
# Epoch 10/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.6587 - accuracy: 0.5612 - val_loss: 0.6166 - val_accuracy: 0.6273
# Epoch 11/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5597 - accuracy: 0.7244 - val_loss: 0.5172 - val_accuracy: 0.7850
# Epoch 12/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5738 - accuracy: 0.6990 - val_loss: 0.5483 - val_accuracy: 0.7249
# Epoch 13/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5239 - accuracy: 0.7705 - val_loss: 0.5077 - val_accuracy: 0.7930
# Epoch 14/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5483 - accuracy: 0.7345 - val_loss: 0.5134 - val_accuracy: 0.7697
# Epoch 15/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5303 - accuracy: 0.7588 - val_loss: 0.5035 - val_accuracy: 0.7906
# Epoch 16/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.5046 - accuracy: 0.7903 - val_loss: 0.5149 - val_accuracy: 0.7837
# Epoch 17/20
# 2000/2000 [==============================] - 19s 9ms/step - loss: 0.5031 - accuracy: 0.7900 - val_loss: 0.4915 - val_accuracy: 0.7972
# Epoch 18/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.4992 - accuracy: 0.7977 - val_loss: 0.5377 - val_accuracy: 0.7705
# Epoch 19/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.4991 - accuracy: 0.7947 - val_loss: 0.4866 - val_accuracy: 0.8060
# Epoch 20/20
# 2000/2000 [==============================] - 18s 9ms/step - loss: 0.4923 - accuracy: 0.8032 - val_loss: 0.4952 - val_accuracy: 0.8026

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_uni_LSTM.history['accuracy'])
plt.plot(history_uni_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_uni_LSTM.history['loss'])
plt.plot(history_uni_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing

uni_loss, uni_accuracy = uni_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {uni_accuracy:.4f}')

y_pred = uni_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_uni_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

uni_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {uni_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.4925 - accuracy: 0.8040
# Test Accuracy: 0.8040
# 313/313 [==============================] - 2s 4ms/step
# F1 Score on Test Set: 0.8069

# %% [markdown]
# # Training and testing on Bi LSTM

# %%
bi_LSTM = Sequential()
bi_LSTM.add(Embedding(input_dim=vocab_size, 
                      output_dim=embedding_dim, 
                      weights=[embedding_matrix], 
                      input_length=maxlen, 
                      trainable=False))
bi_LSTM.add(Bidirectional(LSTM(10)))  # Bidirectional LSTM layer
bi_LSTM.add(Dense(1, activation='sigmoid')) 

optimizer = Adam(learning_rate=1e-3)
bi_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
bi_LSTM.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 256, 100)          10018200
#
#  bidirectional (Bidirection  (None, 20)                8880
#  al)
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 10027101 (38.25 MB)
# Trainable params: 8901 (34.77 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
#Training the bi_LSTM model 

history_bi_LSTM = bi_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 37s 17ms/step - loss: 0.4786 - accuracy: 0.7672 - val_loss: 0.3755 - val_accuracy: 0.8404
# Epoch 2/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.3643 - accuracy: 0.8402 - val_loss: 0.3407 - val_accuracy: 0.8540
# Epoch 3/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.3351 - accuracy: 0.8542 - val_loss: 0.3790 - val_accuracy: 0.8370
# Epoch 4/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.3198 - accuracy: 0.8642 - val_loss: 0.3173 - val_accuracy: 0.8618
# Epoch 5/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.3054 - accuracy: 0.8712 - val_loss: 0.3097 - val_accuracy: 0.8700
# Epoch 6/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.2922 - accuracy: 0.8776 - val_loss: 0.3379 - val_accuracy: 0.8529
# Epoch 7/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2843 - accuracy: 0.8811 - val_loss: 0.3144 - val_accuracy: 0.8671
# Epoch 8/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2758 - accuracy: 0.8848 - val_loss: 0.3092 - val_accuracy: 0.8706
# Epoch 9/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2675 - accuracy: 0.8892 - val_loss: 0.3096 - val_accuracy: 0.8681
# Epoch 10/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2609 - accuracy: 0.8908 - val_loss: 0.3150 - val_accuracy: 0.8698
# Epoch 11/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2551 - accuracy: 0.8947 - val_loss: 0.3100 - val_accuracy: 0.8765
# Epoch 12/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2502 - accuracy: 0.8965 - val_loss: 0.3062 - val_accuracy: 0.8749
# Epoch 13/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2449 - accuracy: 0.8987 - val_loss: 0.3195 - val_accuracy: 0.8721
# Epoch 14/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2416 - accuracy: 0.9011 - val_loss: 0.3194 - val_accuracy: 0.8710
# Epoch 15/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2364 - accuracy: 0.9043 - val_loss: 0.3192 - val_accuracy: 0.8719
# Epoch 16/20
# 2000/2000 [==============================] - 32s 16ms/step - loss: 0.2325 - accuracy: 0.9051 - val_loss: 0.3227 - val_accuracy: 0.8727
# Epoch 17/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.2280 - accuracy: 0.9072 - val_loss: 0.3290 - val_accuracy: 0.8666
# Epoch 18/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.2247 - accuracy: 0.9095 - val_loss: 0.3236 - val_accuracy: 0.8704
# Epoch 19/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.2222 - accuracy: 0.9107 - val_loss: 0.3255 - val_accuracy: 0.8671
# Epoch 20/20
# 2000/2000 [==============================] - 33s 16ms/step - loss: 0.2180 - accuracy: 0.9117 - val_loss: 0.3317 - val_accuracy: 0.8710

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_bi_LSTM.history['accuracy'])
plt.plot(history_bi_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_bi_LSTM.history['loss'])
plt.plot(history_bi_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing

bi_loss, bi_accuracy = bi_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {bi_accuracy:.4f}')

y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)

f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {f1:.4f}')
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3404 - accuracy: 0.8604
# Test Accuracy: 0.8604
# 313/313 [==============================] - 3s 7ms/step
# F1 Score on Test Set: 0.8629

# %%
y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_bi_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

bi_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {bi_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 2s 7ms/step
# F1 Score on Test Set: 0.8629

# %% [markdown]
# # Visualizing the results

# %%
# All test metrics at a glance

data = {
    'Model': ['RNN', 'Uni-LSTM', 'Bi-LSTM'],
    'Accuracy': [rnn_accuracy, uni_accuracy, bi_accuracy],
    'F1 Score': [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1],
    'Loss': [rnn_loss, uni_loss, bi_loss]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Model  Accuracy  F1 Score      Loss
# 0       RNN    0.7231  0.732593  1.375363
# 1  Uni-LSTM    0.8040  0.806897  0.492521
# 2   Bi-LSTM    0.8604  0.862922  0.340415

# %% [markdown]
# **Training accuracy and loss**

# %%
# Extracting information from history objects
epochs = range(1, len(history_rnn.history['accuracy']) + 1)

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, history_rnn.history['accuracy'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['accuracy'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['accuracy'], label='Bi-LSTM', marker='o')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, history_rnn.history['loss'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['loss'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['loss'], label='Bi-LSTM', marker='o')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization/Comparison with Bar charts**

# %%
# Data
accuracy_data = [rnn_accuracy, uni_accuracy, bi_accuracy]
f1_data = [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1]
loss_data = [rnn_loss, uni_loss, bi_loss]
models = ['RNN', 'LSTM', 'Bi-LSTM']

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.bar(models, accuracy_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Accuracy')
plt.ylabel('Accuracy')

# Plotting f1
plt.subplot(1, 3, 2)
plt.bar(models, f1_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test F1')
plt.ylabel('F1 Score')


# Plotting Loss
plt.subplot(1, 3, 3)
plt.bar(models, loss_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Loss')
plt.ylabel('Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Overall performance visualization with heatmaps**

# %%
cms = [cm_rnn, cm_uni_LSTM, cm_bi_LSTM]
model_names = ['rnn', 'uni_LSTM', 'bi_LSTM']

plt.figure(figsize=(18, 6))

for i, cm in enumerate(cms, 1):
    plt.subplot(1, 3, i)
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlGnBu', 
                xticklabels=['Predicted Negative', 'Predicted Positive'],
                yticklabels=['Actual Negative', 'Actual Positive'])
    plt.title(f'Confusion Matrix - {model_names[i-1]}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

plt.tight_layout()
plt.show()
