# %% [markdown]
# # **This notebook is prepared as a project for the reqirement of the course CSE440-Natural Language Processing II of Brac University.**

# %% [markdown]
# **In this notebook, we have used 3 different approaches for sentiment classification on a customized IMDB Dataset. Workflow--->**
# * **Importing/installing necessary libraries**
# * **EDA**
# * **Text Data Preprocessing**
# * **Loading a Pre-trained vector and making an Embedding matrix**
# * **RNN Training and testing**
# * **LSTM Training and testing**
# * **BiLSTM Training and testing**
# * **Result Visualization**

# %% [markdown]
# # Importing/installing necessary libraries

# %%
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')

import matplotlib.pyplot as plt
import seaborn as sns

import re
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, Dense
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from tensorflow.keras.optimizers import Adam

import os
import warnings

warnings.filterwarnings("ignore")
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Creating a dynamic data path**

# %%
'''input the path of the directory 
containing both files '''

dir = '/kaggle/input/'  

for dirname, _, filenames in os.walk(dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        if filename.endswith('.txt'):
            vecPath = os.path.join(dirname, filename)
        else:
            dataPath = os.path.join(dirname, filename)
# Out:
# /kaggle/input/imdb-for-440-project/glove.6B.100d.txt
# /kaggle/input/imdb-for-440-project/imdb_440/IMDB Dataset.csv

# %% [markdown]
# # EDA

# %%
df = pd.read_csv(dataPath)
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(df.dtypes)

# Check for missing values
print(df.isnull().sum())
# Out:
# review       object
# sentiment    object
# dtype: object
# review       0
# sentiment    0
# dtype: int64

# %%
df.sentiment.unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
#data distribution
#balance check

sentiment_distribution = df['sentiment'].value_counts()

# Plotting the distribution
plt.bar(sentiment_distribution.index, sentiment_distribution.values, color=['red', 'green'])
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ![rsz_thanos-perfectly-balanced-as-all-things-should-be.jpg](attachment:3ff44880-3019-4245-a7be-71c8625ced4b.jpg)

# %%
# Calculate text lengths
df['text_length'] = df['review'].apply(len)

# Plot histogram
plt.figure(figsize=(5, 3))
plt.hist(df['text_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Text Lengths')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# Tokenize the text
df['token_length'] = df['review'].apply(lambda x: len(word_tokenize(x)))

# Plot histogram 
plt.figure(figsize=(5, 3))
plt.hist(df['token_length'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Token Lengths')
plt.xlabel('Token Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Preprocessing the text data

# %%
# binary encode sentiments
encoder = LabelEncoder()
df['sentiment'] = encoder.fit_transform(df['sentiment'])

def preprocess_text(text):
    #html tag handling
    text = re.sub(r'<[^>]+>', '', text)

    # Lowercasing
    text = text.lower()

    # Tokenization
    tokens = word_tokenize(text)

    #punctuation and stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]

#     stemmer = PorterStemmer()
#     tokens = [stemmer.stem(word) for word in tokens]

    return ' '.join(tokens)
df['cleaned_review'] = df['review'].apply(preprocess_text)

# Compare the two
print(df[['review', 'cleaned_review']].head())
# Out:
#                                               review  \
# 0  One of the other reviewers has mentioned that ...
# 1  A wonderful little production. <br /><br />The...
# 2  I thought this was a wonderful way to spend ti...
# 3  Basically there's a family where a little boy ...
# 4  Petter Mattei's "Love in the Time of Money" is...
#
#                                       cleaned_review
# 0  one reviewers mentioned watching 1 oz episode ...
# 1  wonderful little production filming technique ...
# 2  thought wonderful way spend time hot summer we...
# 3  basically family little boy jake thinks zombie...
# 4  petter mattei love time money visually stunnin...

# %% [markdown]
# # Loading GloVe and making an Embedding Matrix

# %%
def load_glove_vectors(glovePath):
    embedding_index = {}
    with open(glovePath, 'r', encoding='utf8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embedding_index[word] = coefs
    return embedding_index

# Load GloVe Vectors
glove_vectors = load_glove_vectors(vecPath)

# Tokenize, text ---> sequences
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['cleaned_review'])  
sequences = tokenizer.texts_to_sequences(df['cleaned_review'])

# Create an embedding matrix
embedding_dim = 100
vocab_size = len(tokenizer.word_index) + 1
embedding_matrix = np.zeros((vocab_size, embedding_dim))
for word, i in tokenizer.word_index.items():
    embedding_vector = glove_vectors.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# %% [markdown]
# **Train-test split and padding**

# %%
X = sequences  
y = df['sentiment'].values 

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Padding sequences
maxlen = 256  # Maximum length of all sequences
X_train = pad_sequences(X_train, padding='post', maxlen=maxlen)
X_test = pad_sequences(X_test, padding='post', maxlen=maxlen)

# %% [markdown]
# # Training and testing on RNN

# %%
# Building the model
rnn_model = Sequential()
rnn_model.add(Embedding(input_dim=vocab_size, 
                    output_dim=embedding_dim, 
                    weights=[embedding_matrix], 
                    input_length=maxlen, 
                    trainable=False))
rnn_model.add(Flatten())  # Flatten the output of the embedding layer
rnn_model.add(Dense(10, activation='relu'))
rnn_model.add(Dense(1, activation='sigmoid'))  

# optimizer = Adam(learning_rate=1e-3)
rnn_model.compile(optimizer= 'adam', loss='binary_crossentropy', metrics=['accuracy'])

rnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 256, 100)          10018200
#
#  flatten (Flatten)           (None, 25600)             0
#
#  dense (Dense)               (None, 10)                256010
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10274221 (39.19 MB)
# Trainable params: 256021 (1000.08 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
# Training the model

history_rnn = rnn_model.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 10s 3ms/step - loss: 0.5547 - accuracy: 0.7157 - val_loss: 0.5043 - val_accuracy: 0.7609
# Epoch 2/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.4225 - accuracy: 0.8089 - val_loss: 0.4906 - val_accuracy: 0.7697
# Epoch 3/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.3488 - accuracy: 0.8450 - val_loss: 0.5662 - val_accuracy: 0.7654
# Epoch 4/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.2989 - accuracy: 0.8686 - val_loss: 0.6140 - val_accuracy: 0.7546
# Epoch 5/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.2580 - accuracy: 0.8893 - val_loss: 0.7218 - val_accuracy: 0.7582
# Epoch 6/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.2215 - accuracy: 0.9062 - val_loss: 0.7659 - val_accuracy: 0.7536
# Epoch 7/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.2001 - accuracy: 0.9147 - val_loss: 0.8001 - val_accuracy: 0.7416
# Epoch 8/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1752 - accuracy: 0.9259 - val_loss: 0.9876 - val_accuracy: 0.7487
# Epoch 9/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1570 - accuracy: 0.9347 - val_loss: 1.0317 - val_accuracy: 0.7421
# Epoch 10/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.1443 - accuracy: 0.9407 - val_loss: 1.3193 - val_accuracy: 0.7484
# Epoch 11/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1313 - accuracy: 0.9472 - val_loss: 1.6594 - val_accuracy: 0.7315
# Epoch 12/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1234 - accuracy: 0.9501 - val_loss: 1.5187 - val_accuracy: 0.7444
# Epoch 13/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.1164 - accuracy: 0.9537 - val_loss: 1.3025 - val_accuracy: 0.7265
# Epoch 14/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.1112 - accuracy: 0.9570 - val_loss: 1.6310 - val_accuracy: 0.7412
# Epoch 15/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.1036 - accuracy: 0.9593 - val_loss: 1.6792 - val_accuracy: 0.7347
# Epoch 16/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.1006 - accuracy: 0.9609 - val_loss: 1.5666 - val_accuracy: 0.7299
# Epoch 17/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.1020 - accuracy: 0.9600 - val_loss: 1.7591 - val_accuracy: 0.7440
# Epoch 18/20
# 2000/2000 [==============================] - 5s 3ms/step - loss: 0.0974 - accuracy: 0.9627 - val_loss: 1.9607 - val_accuracy: 0.7404
# Epoch 19/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0941 - accuracy: 0.9642 - val_loss: 1.6499 - val_accuracy: 0.7324
# Epoch 20/20
# 2000/2000 [==============================] - 6s 3ms/step - loss: 0.0876 - accuracy: 0.9664 - val_loss: 2.0116 - val_accuracy: 0.7409

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_rnn.history['accuracy'])
plt.plot(history_rnn.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_rnn.history['loss'])
plt.plot(history_rnn.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#Testing on RNN

rnn_loss, rnn_accuracy = rnn_model.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {rnn_accuracy:.4f}')

y_pred = rnn_model.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_rnn = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

rnn_model_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {rnn_model_f1:.4f}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.0357 - accuracy: 0.7322
# Test Accuracy: 0.7322
# 313/313 [==============================] - 1s 2ms/step
# F1 Score on Test Set: 0.7332

# %% [markdown]
# # Training and testing on LSTM(Unidirectional)

# %%
uni_LSTM = Sequential()
uni_LSTM.add(Embedding(input_dim=vocab_size, 
                       output_dim=embedding_dim, 
                       weights=[embedding_matrix], 
                       input_length=maxlen, 
                       trainable=False))
uni_LSTM.add(LSTM(10, activation='relu'))  # Unidirectional LSTM layer
uni_LSTM.add(Dense(1, activation='sigmoid'))  

optimizer = Adam(learning_rate=1e-3)
uni_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
uni_LSTM.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 256, 100)          10018200
#
#  lstm (LSTM)                 (None, 10)                4440
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 10022651 (38.23 MB)
# Trainable params: 4451 (17.39 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
# Training the uni_LSTM model

history_uni_LSTM = uni_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16)
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - 312s 155ms/step - loss: 0.7033 - accuracy: 0.5053 - val_loss: 0.6964 - val_accuracy: 0.5350
# Epoch 2/20
# 2000/2000 [==============================] - 306s 153ms/step - loss: 0.6900 - accuracy: 0.5341 - val_loss: 0.6885 - val_accuracy: 0.5321
# Epoch 3/20
# 2000/2000 [==============================] - 304s 152ms/step - loss: 0.6875 - accuracy: 0.5353 - val_loss: 0.6877 - val_accuracy: 0.5330
# Epoch 4/20
# 2000/2000 [==============================] - 306s 153ms/step - loss: 0.6872 - accuracy: 0.5351 - val_loss: 0.6891 - val_accuracy: 0.5316
# Epoch 5/20
# 2000/2000 [==============================] - 306s 153ms/step - loss: 0.6872 - accuracy: 0.5356 - val_loss: 0.6875 - val_accuracy: 0.5330
# Epoch 6/20
# 2000/2000 [==============================] - 304s 152ms/step - loss: 0.6871 - accuracy: 0.5355 - val_loss: 0.6875 - val_accuracy: 0.5332
# Epoch 7/20
# 2000/2000 [==============================] - 303s 152ms/step - loss: 0.6869 - accuracy: 0.5361 - val_loss: 0.6906 - val_accuracy: 0.5257
# Epoch 8/20
# 2000/2000 [==============================] - 302s 151ms/step - loss: 0.6871 - accuracy: 0.5364 - val_loss: 0.6872 - val_accuracy: 0.5347
# Epoch 9/20
# 2000/2000 [==============================] - 300s 150ms/step - loss: 0.6871 - accuracy: 0.5362 - val_loss: 0.6884 - val_accuracy: 0.5291
# Epoch 10/20
# 2000/2000 [==============================] - 300s 150ms/step - loss: 0.6867 - accuracy: 0.5366 - val_loss: 0.6876 - val_accuracy: 0.5340
# Epoch 11/20
# 2000/2000 [==============================] - 306s 153ms/step - loss: 0.6866 - accuracy: 0.5366 - val_loss: 0.6880 - val_accuracy: 0.5341
# Epoch 12/20
# 2000/2000 [==============================] - 306s 153ms/step - loss: 0.6866 - accuracy: 0.5382 - val_loss: 0.6867 - val_accuracy: 0.5383
# Epoch 13/20
# 2000/2000 [==============================] - 307s 153ms/step - loss: 0.6857 - accuracy: 0.5423 - val_loss: 0.6852 - val_accuracy: 0.5440
# Epoch 14/20
# 2000/2000 [==============================] - 304s 152ms/step - loss: 0.6816 - accuracy: 0.5579 - val_loss: 0.6766 - val_accuracy: 0.5746
# Epoch 15/20
# 2000/2000 [==============================] - 304s 152ms/step - loss: 0.6590 - accuracy: 0.6083 - val_loss: 0.6493 - val_accuracy: 0.6313
# Epoch 16/20
# 2000/2000 [==============================] - 304s 152ms/step - loss: 0.6407 - accuracy: 0.6352 - val_loss: 0.6376 - val_accuracy: 0.6480
# Epoch 17/20
# 2000/2000 [==============================] - 304s 152ms/step - loss: 0.6027 - accuracy: 0.6746 - val_loss: 0.5750 - val_accuracy: 0.7036
# Epoch 18/20
# 2000/2000 [==============================] - 303s 151ms/step - loss: 0.6792 - accuracy: 0.5305 - val_loss: 0.6898 - val_accuracy: 0.5088
# Epoch 19/20
# 2000/2000 [==============================] - 302s 151ms/step - loss: 0.6368 - accuracy: 0.6234 - val_loss: 0.5579 - val_accuracy: 0.7201
# Epoch 20/20
# 2000/2000 [==============================] - 299s 150ms/step - loss: 0.4880 - accuracy: 0.7610 - val_loss: 0.4586 - val_accuracy: 0.7900

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_uni_LSTM.history['accuracy'])
plt.plot(history_uni_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_uni_LSTM.history['loss'])
plt.plot(history_uni_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing

uni_loss, uni_accuracy = uni_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {uni_accuracy:.4f}')

y_pred = uni_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_uni_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

uni_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {uni_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 10s 32ms/step - loss: 0.4581 - accuracy: 0.7862
# Test Accuracy: 0.7862
# 313/313 [==============================] - 10s 32ms/step
# F1 Score on Test Set: 0.7736

# %% [markdown]
# # Training and testing on Bi LSTM

# %%
bi_LSTM = Sequential()
bi_LSTM.add(Embedding(input_dim=vocab_size, 
                      output_dim=embedding_dim, 
                      weights=[embedding_matrix], 
                      input_length=maxlen, 
                      trainable=False))
bi_LSTM.add(Bidirectional(LSTM(10, activation='relu')))  # Bidirectional LSTM layer
bi_LSTM.add(Dense(1, activation='sigmoid')) 

optimizer = Adam(learning_rate=1e-3)
bi_LSTM.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
bi_LSTM.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 256, 100)          10018200
#
#  bidirectional (Bidirection  (None, 20)                8880
#  al)
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 10027101 (38.25 MB)
# Trainable params: 8901 (34.77 KB)
# Non-trainable params: 10018200 (38.22 MB)
# _________________________________________________________________

# %%
#Training the bi_LSTM model 
'''saving the best model while training 
because of the exploding gradiant problem'''

model_checkpoint = ModelCheckpoint(filepath='/kaggle/working/bi_LSTM_best.h5', 
                                   monitor='val_loss', 
                                   save_best_only=True,
                                   mode='min',
                                   verbose=1)

history_bi_LSTM = bi_LSTM.fit(X_train, y_train, epochs=20, verbose=1, validation_split=0.2, batch_size=16, callbacks=[model_checkpoint])
# Out:
# Epoch 1/20
# 2000/2000 [==============================] - ETA: 0s - loss: 2672818.7500 - accuracy: 0.6730
# Epoch 1: val_loss improved from inf to 0.54793, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 574s 286ms/step - loss: 2672818.7500 - accuracy: 0.6730 - val_loss: 0.5479 - val_accuracy: 0.7303
# Epoch 2/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5183 - accuracy: 0.7505
# Epoch 2: val_loss improved from 0.54793 to 0.45633, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 578s 289ms/step - loss: 0.5183 - accuracy: 0.7505 - val_loss: 0.4563 - val_accuracy: 0.7909
# Epoch 3/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.8041
# Epoch 3: val_loss improved from 0.45633 to 0.39655, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 588s 294ms/step - loss: 0.4369 - accuracy: 0.8041 - val_loss: 0.3966 - val_accuracy: 0.8281
# Epoch 4/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3911 - accuracy: 0.8270
# Epoch 4: val_loss improved from 0.39655 to 0.37432, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 585s 292ms/step - loss: 0.3911 - accuracy: 0.8270 - val_loss: 0.3743 - val_accuracy: 0.8364
# Epoch 5/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3688 - accuracy: 0.8387
# Epoch 5: val_loss improved from 0.37432 to 0.34940, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 572s 286ms/step - loss: 0.3688 - accuracy: 0.8387 - val_loss: 0.3494 - val_accuracy: 0.8487
# Epoch 6/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3515 - accuracy: 0.8466
# Epoch 6: val_loss improved from 0.34940 to 0.34192, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 570s 285ms/step - loss: 0.3515 - accuracy: 0.8466 - val_loss: 0.3419 - val_accuracy: 0.8546
# Epoch 7/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3418 - accuracy: 0.8526
# Epoch 7: val_loss improved from 0.34192 to 0.33226, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 566s 283ms/step - loss: 0.3418 - accuracy: 0.8526 - val_loss: 0.3323 - val_accuracy: 0.8572
# Epoch 8/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3324 - accuracy: 0.8564
# Epoch 8: val_loss improved from 0.33226 to 0.32946, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 572s 286ms/step - loss: 0.3324 - accuracy: 0.8564 - val_loss: 0.3295 - val_accuracy: 0.8583
# Epoch 9/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3242 - accuracy: 0.8588
# Epoch 9: val_loss improved from 0.32946 to 0.32395, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 574s 287ms/step - loss: 0.3242 - accuracy: 0.8588 - val_loss: 0.3240 - val_accuracy: 0.8643
# Epoch 10/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3146 - accuracy: 0.8641
# Epoch 10: val_loss improved from 0.32395 to 0.32373, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 575s 287ms/step - loss: 0.3146 - accuracy: 0.8641 - val_loss: 0.3237 - val_accuracy: 0.8626
# Epoch 11/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3100 - accuracy: 0.8665
# Epoch 11: val_loss did not improve from 0.32373
# 2000/2000 [==============================] - 572s 286ms/step - loss: 0.3100 - accuracy: 0.8665 - val_loss: 0.3302 - val_accuracy: 0.8589
# Epoch 12/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3015 - accuracy: 0.8706
# Epoch 12: val_loss improved from 0.32373 to 0.32248, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 572s 286ms/step - loss: 0.3015 - accuracy: 0.8706 - val_loss: 0.3225 - val_accuracy: 0.8641
# Epoch 13/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.8745
# Epoch 13: val_loss did not improve from 0.32248
# 2000/2000 [==============================] - 566s 283ms/step - loss: 0.2960 - accuracy: 0.8745 - val_loss: 0.3245 - val_accuracy: 0.8601
# Epoch 14/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2908 - accuracy: 0.8758
# Epoch 14: val_loss improved from 0.32248 to 0.32008, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 570s 285ms/step - loss: 0.2908 - accuracy: 0.8758 - val_loss: 0.3201 - val_accuracy: 0.8676
# Epoch 15/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.8793
# Epoch 15: val_loss improved from 0.32008 to 0.31652, saving model to /kaggle/working/bi_LSTM_best.h5
# 2000/2000 [==============================] - 573s 286ms/step - loss: 0.2838 - accuracy: 0.8793 - val_loss: 0.3165 - val_accuracy: 0.8668
# Epoch 16/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.8796
# Epoch 16: val_loss did not improve from 0.31652
# 2000/2000 [==============================] - 574s 287ms/step - loss: 0.2806 - accuracy: 0.8796 - val_loss: 0.3170 - val_accuracy: 0.8669
# Epoch 17/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.8821
# Epoch 17: val_loss did not improve from 0.31652
# 2000/2000 [==============================] - 573s 286ms/step - loss: 0.2758 - accuracy: 0.8821 - val_loss: 0.3207 - val_accuracy: 0.8658
# Epoch 18/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.8264
# Epoch 18: val_loss did not improve from 0.31652
# 2000/2000 [==============================] - 585s 292ms/step - loss: 0.5467 - accuracy: 0.8264 - val_loss: 0.4167 - val_accuracy: 0.8190
# Epoch 19/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3917 - accuracy: 0.8291
# Epoch 19: val_loss did not improve from 0.31652
# 2000/2000 [==============================] - 568s 284ms/step - loss: 0.3917 - accuracy: 0.8291 - val_loss: 0.4035 - val_accuracy: 0.8210
# Epoch 20/20
# 2000/2000 [==============================] - ETA: 0s - loss: 0.3819 - accuracy: 0.8338
# Epoch 20: val_loss did not improve from 0.31652
# 2000/2000 [==============================] - 570s 285ms/step - loss: 0.3819 - accuracy: 0.8338 - val_loss: 0.3961 - val_accuracy: 0.8238

# %%
# Plot training and validation curves
plt.figure(figsize=(10, 5))

# Plot training & validation accuracy values
plt.subplot(1, 2, 1)
plt.plot(history_bi_LSTM.history['accuracy'])
plt.plot(history_bi_LSTM.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history_bi_LSTM.history['loss'])
plt.plot(history_bi_LSTM.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
#testing

bi_LSTM = load_model('/kaggle/working/bi_LSTM_best.h5')

bi_loss, bi_accuracy = bi_LSTM.evaluate(X_test, y_test, verbose=1)
print(f'Test Accuracy: {bi_accuracy:.4f}')

y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)

f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {f1:.4f}')
# Out:
# 313/313 [==============================] - 21s 66ms/step - loss: 0.3182 - accuracy: 0.8629
# Test Accuracy: 0.8629
# 313/313 [==============================] - 21s 66ms/step
# F1 Score on Test Set: 0.8666

# %%
y_pred = bi_LSTM.predict(X_test)
y_pred_binary = (y_pred > 0.5).astype(int)
cm_bi_LSTM = confusion_matrix(y_test, y_pred_binary) #conf mat for future visuals

bi_LSTM_f1 = f1_score(y_test, y_pred_binary)
print(f'F1 Score on Test Set: {bi_LSTM_f1:.4f}')
# Out:
# 313/313 [==============================] - 20s 63ms/step
# F1 Score on Test Set: 0.8666

# %% [markdown]
# # Visualizing the results

# %%
# All test metrics at a glance

data = {
    'Model': ['RNN', 'Uni-LSTM', 'Bi-LSTM'],
    'Accuracy': [rnn_accuracy, uni_accuracy, bi_accuracy],
    'F1 Score': [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1],
    'Loss': [rnn_loss, uni_loss, bi_loss]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Model  Accuracy  F1 Score      Loss
# 0       RNN    0.7322  0.733214  2.035659
# 1  Uni-LSTM    0.7862  0.773565  0.458093
# 2   Bi-LSTM    0.8629  0.866621  0.318164

# %% [markdown]
# **Training accuracy and loss**

# %%
# Extracting information from history objects
epochs = range(1, len(history_rnn.history['accuracy']) + 1)

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs, history_rnn.history['accuracy'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['accuracy'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['accuracy'], label='Bi-LSTM', marker='o')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, history_rnn.history['loss'], label='RNN', marker='o')
plt.plot(epochs, history_uni_LSTM.history['loss'], label='LSTM', marker='o')
plt.plot(epochs, history_bi_LSTM.history['loss'], label='Bi-LSTM', marker='o')
plt.title('Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Visualization/Comparison with Bar charts**

# %%
# Data
accuracy_data = [rnn_accuracy, uni_accuracy, bi_accuracy]
f1_data = [rnn_model_f1, uni_LSTM_f1, bi_LSTM_f1]
loss_data = [rnn_loss, uni_loss, bi_loss]
models = ['RNN', 'LSTM', 'Bi-LSTM']

# Plotting Accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 3, 1)
plt.bar(models, accuracy_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Accuracy')
plt.ylabel('Accuracy')

# Plotting f1
plt.subplot(1, 3, 2)
plt.bar(models, f1_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test F1')
plt.ylabel('F1 Score')


# Plotting Loss
plt.subplot(1, 3, 3)
plt.bar(models, loss_data, color=['rebeccapurple', 'seagreen', 'salmon'])
plt.title('Test Loss')
plt.ylabel('Loss')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Overall performance visualization with heatmaps**

# %%
cms = [cm_rnn, cm_uni_LSTM, cm_bi_LSTM]
model_names = ['rnn', 'uni_LSTM', 'bi_LSTM']

plt.figure(figsize=(18, 6))

for i, cm in enumerate(cms, 1):
    plt.subplot(1, 3, i)
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlGnBu', 
                xticklabels=['Predicted Negative', 'Predicted Positive'],
                yticklabels=['Actual Negative', 'Actual Positive'])
    plt.title(f'Confusion Matrix - {model_names[i-1]}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')

plt.tight_layout()
plt.show()
